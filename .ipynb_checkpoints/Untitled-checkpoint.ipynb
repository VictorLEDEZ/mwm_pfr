# %%
import numpy as np
import time
import cv2
from darkflow.net.build import TFNet
import matplotlib.pyplot as plt
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/clementl/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/2l/8sf4d91x69q2_ytbt4ry_znr0000gn/T/ipykernel_3926/3354439849.py", line 4, in <module>
#     from darkflow.net.build import TFNet
#   File "/Users/clementl/Desktop/Cours_BGD_Telecom_Paris/Projet_Fil_Rouge/darkflow/darkflow/net/build.py", line 5, in <module>
#     from .ops import op_create, identity
# ...
